# %% [markdown]
# # FINAL SELECTED 10 FEATURES:

# %%
selected = ['nosi','dit','cbo','rfc','maxNestedBlocks',
            'uniqueWordsQty','assignmentsQty','numbersQty',
            'tryCatchQty','parenthesizedExpsQty']

# %%
import pandas as pd
dataset = pd.read_csv("DillibabuSarva_DefectDataset.csv")

# %%
# BEST code for your thesis - with sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# Feature selection result
selected_features = ['nosi','dit','cbo','rfc','maxNestedBlocks',
                     'uniqueWordsQty','assignmentsQty','numbersQty',
                     'tryCatchQty','parenthesizedExpsQty']

X = dataset[selected_features]
y = dataset['defect']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

# Random Forest is best for this dataset
rf = RandomForestClassifier(
    n_estimators=200, max_depth=10, 
    class_weight='balanced', random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_proba = rf.predict_proba(X_test)[:,1]

print(f"AUC: {roc_auc_score(y_test, y_proba):.3f}")
print(classification_report(y_test, y_pred))

# Feature importance
import pandas as pd
pd.DataFrame({
    'feature': selected_features,
    'importance': rf.feature_importances_
}).sort_values('importance', ascending=False)
# Out:
# AUC: 0.794
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75       908
#            1       0.74      0.80      0.77       908
#
#     accuracy                           0.76      1816
#    macro avg       0.76      0.76      0.76      1816
# weighted avg       0.76      0.76      0.76      1816
#                 feature  importance
# 0                  nosi    0.537652
# 2                   cbo    0.074217
# 1                   dit    0.068316
# 5        uniqueWordsQty    0.067521
# 3                   rfc    0.065659
# 6        assignmentsQty    0.061133
# 7            numbersQty    0.044824
# 4       maxNestedBlocks    0.032217
# 9  parenthesizedExpsQty    0.024701
# 8           tryCatchQty    0.023760
