# %%
import pandas as pd
from Univariate import Univariate

# %%
dataset=pd.read_csv("DillibabuSarva_DefectDataset.csv")

# %%
dataset
# Out:
#                                             SHA  cbo  wmc  dit  rfc  lcom  \
# 0     7a955fd6c7de2bd912be544dcfe77f9173a7aa600    5   60    2   55   189
# 1     000f1ab4780fc9460975791c52597f7c04e15be70    3   10    1    1     9
# 2     000f1ab4780fc9460975791c52597f7c04e15be71    3   10    1    1     9
# 3     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c270   20   59    3   63   189
# 4     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c271   21   58    2   61   189
# ...                                         ...  ...  ...  ...  ...   ...
# 6047  ffd1ed788cbf10bed00d49d79c7ee44250c36ac11   52  124   12  144   963
# 6048  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c0   24   27    2   46     4
# 6049  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c1   22   27    1   46     4
# 6050  ffe7c9989a4553d35fd1d5041d0cece0a673a0c80    3   12    2   12    28
# 6051  ffe7c9989a4553d35fd1d5041d0cece0a673a0c81    5   11    1   11    21
#
#       totalMethods  totalFields  nosi  loc  ...  tryCatchQty  \
# 0               27            5    30  247  ...            4
# 1                7            4     1   38  ...            0
# 2                7            4     0   38  ...            0
# 3               24            9     4  262  ...            0
# 4               24            9     0  260  ...            0
# ...            ...          ...   ...  ...  ...          ...
# 6047           110            9     0  804  ...            0
# 6048             8            8     0  126  ...            0
# 6049             8            8     0  126  ...            0
# 6050             8            0     1   67  ...            2
# 6051             7            0     0   62  ...            2
#
#       parenthesizedExpsQty  stringLiteralsQty  numbersQty  assignmentsQty  \
# 0                        2                 47           9              27
# 1                        0                  0          22               4
# 2                        0                  0          22               4
# 3                        6                  6          14              45
# 4                        6                  6          14              45
# ...                    ...                ...         ...             ...
# 6047                     0                 26          16              32
# 6048                     1                  3          14              27
# 6049                     1                  3          14              27
# 6050                     0                  0           2              10
# 6051                     0                  0           1               9
#
#       mathOperationsQty  variablesQty  maxNestedBlocks  uniqueWordsQty  defect
# 0                     5            17                3             191       0
# 1                     0             4                2              69       0
# 2                     0             4                2              69       1
# 3                     8            41                4             222       0
# 4                     8            41                4             222       1
# ...                 ...           ...              ...             ...     ...
# 6047                  4            30                6             689       1
# 6048                  0            24                3             108       0
# 6049                  0            24                3             108       1
# 6050                  0             8                2              36       0
# 6051                  0             7                2              37       1
#
# [6052 rows x 23 columns]

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                                             SHA  cbo  wmc  dit  rfc  lcom  \
# 0     7a955fd6c7de2bd912be544dcfe77f9173a7aa600    5   60    2   55   189
# 1     000f1ab4780fc9460975791c52597f7c04e15be70    3   10    1    1     9
# 2     000f1ab4780fc9460975791c52597f7c04e15be71    3   10    1    1     9
# 3     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c270   20   59    3   63   189
# 4     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c271   21   58    2   61   189
# ...                                         ...  ...  ...  ...  ...   ...
# 6047  ffd1ed788cbf10bed00d49d79c7ee44250c36ac11   52  124   12  144   963
# 6048  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c0   24   27    2   46     4
# 6049  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c1   22   27    1   46     4
# 6050  ffe7c9989a4553d35fd1d5041d0cece0a673a0c80    3   12    2   12    28
# 6051  ffe7c9989a4553d35fd1d5041d0cece0a673a0c81    5   11    1   11    21
#
#       totalMethods  totalFields  nosi  loc  ...  tryCatchQty  \
# 0               27            5    30  247  ...            4
# 1                7            4     1   38  ...            0
# 2                7            4     0   38  ...            0
# 3               24            9     4  262  ...            0
# 4               24            9     0  260  ...            0
# ...            ...          ...   ...  ...  ...          ...
# 6047           110            9     0  804  ...            0
# 6048             8            8     0  126  ...            0
# 6049             8            8     0  126  ...            0
# 6050             8            0     1   67  ...            2
# 6051             7            0     0   62  ...            2
#
#       parenthesizedExpsQty  stringLiteralsQty  numbersQty  assignmentsQty  \
# 0                        2                 47           9              27
# 1                        0                  0          22               4
# 2                        0                  0          22               4
# 3                        6                  6          14              45
# 4                        6                  6          14              45
# ...                    ...                ...         ...             ...
# 6047                     0                 26          16              32
# 6048                     1                  3          14              27
# 6049                     1                  3          14              27
# 6050                     0                  0           2              10
# 6051                     0                  0           1               9
#
#       mathOperationsQty  variablesQty  maxNestedBlocks  uniqueWordsQty  defect
# 0                     5            17                3             191       0
# 1                     0             4                2              69       0
# 2                     0             4                2              69       1
# 3                     8            41                4             222       0
# 4                     8            41                4             222       1
# ...                 ...           ...              ...             ...     ...
# 6047                  4            30                6             689       1
# 6048                  0            24                3             108       0
# 6049                  0            24                3             108       1
# 6050                  0             8                2              36       0
# 6051                  0             7                2              37       1
#
# [6052 rows x 23 columns]>

# %%
dataset.columns
# Out:
# Index(['SHA', 'cbo', 'wmc', 'dit', 'rfc', 'lcom', 'totalMethods',
#        'totalFields', 'nosi', 'loc', 'returnQty', 'loopQty', 'comparisonsQty',
#        'tryCatchQty', 'parenthesizedExpsQty', 'stringLiteralsQty',
#        'numbersQty', 'assignmentsQty', 'mathOperationsQty', 'variablesQty',
#        'maxNestedBlocks', 'uniqueWordsQty', 'defect'],
#       dtype='object')

# %%
quan,qual=Univariate.quanQual(dataset)

# %%
quan
# Out:
# ['cbo',
#  'wmc',
#  'dit',
#  'rfc',
#  'lcom',
#  'totalMethods',
#  'totalFields',
#  'nosi',
#  'loc',
#  'returnQty',
#  'loopQty',
#  'comparisonsQty',
#  'tryCatchQty',
#  'parenthesizedExpsQty',
#  'stringLiteralsQty',
#  'numbersQty',
#  'assignmentsQty',
#  'mathOperationsQty',
#  'variablesQty',
#  'maxNestedBlocks',
#  'uniqueWordsQty',
#  'defect']

# %%
qual

# %%
dataset
# Out:
#                                             SHA  cbo  wmc  dit  rfc  lcom  \
# 0     7a955fd6c7de2bd912be544dcfe77f9173a7aa600    5   60    2   55   189
# 1     000f1ab4780fc9460975791c52597f7c04e15be70    3   10    1    1     9
# 2     000f1ab4780fc9460975791c52597f7c04e15be71    3   10    1    1     9
# 3     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c270   20   59    3   63   189
# 4     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c271   21   58    2   61   189
# ...                                         ...  ...  ...  ...  ...   ...
# 6047  ffd1ed788cbf10bed00d49d79c7ee44250c36ac11   52  124   12  144   963
# 6048  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c0   24   27    2   46     4
# 6049  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c1   22   27    1   46     4
# 6050  ffe7c9989a4553d35fd1d5041d0cece0a673a0c80    3   12    2   12    28
# 6051  ffe7c9989a4553d35fd1d5041d0cece0a673a0c81    5   11    1   11    21
#
#       totalMethods  totalFields  nosi  loc  ...  tryCatchQty  \
# 0               27            5    30  247  ...            4
# 1                7            4     1   38  ...            0
# 2                7            4     0   38  ...            0
# 3               24            9     4  262  ...            0
# 4               24            9     0  260  ...            0
# ...            ...          ...   ...  ...  ...          ...
# 6047           110            9     0  804  ...            0
# 6048             8            8     0  126  ...            0
# 6049             8            8     0  126  ...            0
# 6050             8            0     1   67  ...            2
# 6051             7            0     0   62  ...            2
#
#       parenthesizedExpsQty  stringLiteralsQty  numbersQty  assignmentsQty  \
# 0                        2                 47           9              27
# 1                        0                  0          22               4
# 2                        0                  0          22               4
# 3                        6                  6          14              45
# 4                        6                  6          14              45
# ...                    ...                ...         ...             ...
# 6047                     0                 26          16              32
# 6048                     1                  3          14              27
# 6049                     1                  3          14              27
# 6050                     0                  0           2              10
# 6051                     0                  0           1               9
#
#       mathOperationsQty  variablesQty  maxNestedBlocks  uniqueWordsQty  defect
# 0                     5            17                3             191       0
# 1                     0             4                2              69       0
# 2                     0             4                2              69       1
# 3                     8            41                4             222       0
# 4                     8            41                4             222       1
# ...                 ...           ...              ...             ...     ...
# 6047                  4            30                6             689       1
# 6048                  0            24                3             108       0
# 6049                  0            24                3             108       1
# 6050                  0             8                2              36       0
# 6051                  0             7                2              37       1
#
# [6052 rows x 23 columns]

# %% [markdown]
# # Central Tendency

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of                                             SHA  cbo  wmc  dit  rfc  lcom  \
# 0     7a955fd6c7de2bd912be544dcfe77f9173a7aa600    5   60    2   55   189
# 1     000f1ab4780fc9460975791c52597f7c04e15be70    3   10    1    1     9
# 2     000f1ab4780fc9460975791c52597f7c04e15be71    3   10    1    1     9
# 3     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c270   20   59    3   63   189
# 4     0024dbdd6ba3cc7797cc0b1ae537dcdc488c4c271   21   58    2   61   189
# ...                                         ...  ...  ...  ...  ...   ...
# 6047  ffd1ed788cbf10bed00d49d79c7ee44250c36ac11   52  124   12  144   963
# 6048  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c0   24   27    2   46     4
# 6049  ffdf4a3fcccb7489548c6a2ff6af7cebc92a180c1   22   27    1   46     4
# 6050  ffe7c9989a4553d35fd1d5041d0cece0a673a0c80    3   12    2   12    28
# 6051  ffe7c9989a4553d35fd1d5041d0cece0a673a0c81    5   11    1   11    21
#
#       totalMethods  totalFields  nosi  loc  ...  tryCatchQty  \
# 0               27            5    30  247  ...            4
# 1                7            4     1   38  ...            0
# 2                7            4     0   38  ...            0
# 3               24            9     4  262  ...            0
# 4               24            9     0  260  ...            0
# ...            ...          ...   ...  ...  ...          ...
# 6047           110            9     0  804  ...            0
# 6048             8            8     0  126  ...            0
# 6049             8            8     0  126  ...            0
# 6050             8            0     1   67  ...            2
# 6051             7            0     0   62  ...            2
#
#       parenthesizedExpsQty  stringLiteralsQty  numbersQty  assignmentsQty  \
# 0                        2                 47           9              27
# 1                        0                  0          22               4
# 2                        0                  0          22               4
# 3                        6                  6          14              45
# 4                        6                  6          14              45
# ...                    ...                ...         ...             ...
# 6047                     0                 26          16              32
# 6048                     1                  3          14              27
# 6049                     1                  3          14              27
# 6050                     0                  0           2              10
# 6051                     0                  0           1               9
#
#       mathOperationsQty  variablesQty  maxNestedBlocks  uniqueWordsQty  defect
# 0                     5            17                3             191       0
# 1                     0             4                2              69       0
# 2                     0             4                2              69       1
# 3                     8            41                4             222       0
# 4                     8            41                4             222       1
# ...                 ...           ...              ...             ...     ...
# 6047                  4            30                6             689       1
# 6048                  0            24                3             108       0
# 6049                  0            24                3             108       1
# 6050                  0             8                2              36       0
# 6051                  0             7                2              37       1
#
# [6052 rows x 23 columns]>

# %%
freqTable = Univariate.freqTable(quan,dataset)

# %%
freqTable
# Out:
#      Unique_Values  Frequency  Relative_Frequency     Cusum
# 0                6        258            0.042631  0.042631
# 1                3        229            0.037839  0.080469
# 2                5        221            0.036517  0.116986
# 3                7        219            0.036186  0.153173
# 4                4        217            0.035856  0.189028
# ..             ...        ...                 ...       ...
# 197            186          1            0.000165  0.999339
# 198            117          1            0.000165  0.999504
# 199            161          1            0.000165  0.999670
# 200            467          1            0.000165  0.999835
# 201            114          1            0.000165  1.000000
#
# [202 rows x 4 columns]

# %%
descriptive = Univariate.Univariate(dataset,quan)

# %%
descriptive
# Out:
#                   cbo           wmc         dit          rfc             lcom  \
# Mean        27.493721     86.177958    4.599141    68.954395      1242.030238
# Median           18.0          45.0         2.0         44.0             43.0
# Mode                9             6           1            0                0
# Q1:25%            9.0          18.0         1.0         18.0              4.0
# Q2:50%           18.0          45.0         2.0         44.0             43.0
# Q3:75%           34.0         100.0         4.0         89.0            267.0
# 99%            175.98         572.0        39.0       435.92          21393.0
# Q4:100%           419          1714         285         1203           199855
# IQR              25.0          82.0         3.0         71.0            263.0
# 1.5rule          37.5         123.0         4.5        106.5            394.5
# Lesser          -28.5        -105.0        -3.5        -88.5           -390.5
# Greater          71.5         223.0         8.5        195.5            661.5
# Min                 0             0           1            0                0
# Max               419          1714         285         1203           199855
# kurtosis    28.686101     49.207785  284.220412    29.278294       304.529231
# skew         4.278873      5.624929   12.464871       4.0708        16.140791
# Var       1103.224717  18516.991462   86.275246  7356.771346  89283775.716982
# Std         33.214827    136.077153    9.288447    85.771623      9449.009245
#
#          totalMethods totalFields        nosi            loc    returnQty  \
# Mean        33.497852   14.049405    5.945142      442.07419    25.410112
# Median           17.0         7.0         0.0          230.0         12.0
# Mode                6           0           0             32            0
# Q1:25%            8.0         3.0         0.0           93.0          4.0
# Q2:50%           17.0         7.0         0.0          230.0         12.0
# Q3:75%           39.0        18.0         3.0         521.25         28.0
# 99%             270.0       96.49       82.49         3319.0        229.0
# Q4:100%           758         903         475           8832          579
# IQR              31.0        15.0         3.0         428.25         24.0
# 1.5rule          46.5        22.5         4.5        642.375         36.0
# Lesser          -38.5       -19.5        -4.5       -549.375        -32.0
# Greater          85.5        40.5         7.5       1163.625         64.0
# Min                 0           0           0              6            0
# Max               758         903         475           8832          579
# kurtosis    58.777083  466.580288  179.862098      44.072895    44.183177
# skew         6.135325   15.638877   11.978757       5.248001     5.784585
# Var       2868.352169  678.656128  638.222077  464532.326837  2214.490184
# Std         53.556999   26.051029   25.263058     681.566084     47.05837
#
#           ... tryCatchQty parenthesizedExpsQty stringLiteralsQty  numbersQty  \
# Mean      ...    3.218275             5.267845         36.727859   31.120621
# Median    ...         1.0                  1.0              12.0         9.0
# Mode      ...           0                    0                 0           0
# Q1:25%    ...         0.0                  0.0               3.0         2.0
# Q2:50%    ...         1.0                  1.0              12.0         9.0
# Q3:75%    ...         3.0                  5.0              34.0        29.0
# 99%       ...        44.0                56.49             409.0      365.43
# Q4:100%   ...         125                  218              4566        2856
# IQR       ...         3.0                  5.0              31.0        27.0
# 1.5rule   ...         4.5                  7.5              46.5        40.5
# Lesser    ...        -4.5                 -7.5             -43.5       -38.5
# Greater   ...         7.5                 12.5              80.5        69.5
# Min       ...           0                    0                 0           0
# Max       ...         125                  218              4566        2856
# kurtosis  ...   65.527993            83.486643        768.694656  407.798771
# skew      ...    6.901486             7.662383         22.754908   14.849985
# Var       ...   73.434913           194.787774      14159.967738  7347.14129
# Std       ...    8.569417            13.956639        118.995663   85.715467
#
#          assignmentsQty mathOperationsQty variablesQty maxNestedBlocks  \
# Mean          65.899042         15.794118     49.70043        5.041143
# Median             34.0               4.0         27.0             4.0
# Mode                  0                 0            7               3
# Q1:25%             13.0               1.0         10.0             2.0
# Q2:50%             34.0               4.0         27.0             4.0
# Q3:75%             80.0              14.0         62.0             6.0
# 99%              439.49             175.0       315.49            31.0
# Q4:100%            2016               501         1050              77
# IQR                67.0              13.0         52.0             4.0
# 1.5rule           100.5              19.5         78.0             6.0
# Lesser            -87.5             -18.5        -68.0            -4.0
# Greater           180.5              33.5        140.0            12.0
# Min                   0                 0            0               0
# Max                2016               501         1050              77
# kurtosis      72.283269         58.352692    52.705855       26.914532
# skew           6.064817          6.645404     5.474408        4.159365
# Var        10302.488401       1600.934304  5260.754566       35.058132
# Std          101.501174         40.011677    72.531059        5.920991
#
#          uniqueWordsQty    defect
# Mean         219.283212       0.5
# Median            139.0       0.5
# Mode                 60         0
# Q1:25%             74.0       0.0
# Q2:50%            139.0       0.5
# Q3:75%            269.0       1.0
# 99%             1284.45       1.0
# Q4:100%            3345         1
# IQR               195.0       1.0
# 1.5rule           292.5       1.5
# Lesser           -218.5      -1.5
# Greater           561.5       2.5
# Min                   5         0
# Max                3345         1
# kurtosis      30.682029 -2.000661
# skew           4.375306       0.0
# Var        71360.948698  0.250041
# Std          267.134701  0.500041
#
# [18 rows x 22 columns]

# %%
"""Here we are using RandomForest - tree models are 100% robust to outliers. No need to replace.
In software defect data, high cbo=200, loc=5000 is NOT an outlier, it's a genuine complex class that is actually defective. 
If we replace it, we will lose signal.
Thesis justification:"Outliers were retained as tree-based ensemble models (Random Forest) are inherently robust to extreme values, 
and high metric values represent genuinely complex, defect-prone classes rather than measurement errors." """
# Out:
# 'Here we are using RandomForest - tree models are 100% robust to outliers. No need to replace.\nIn software defect data, high cbo=200, loc=5000 is NOT an outlier, it\'s a genuine complex class that is actually defective. \nIf we replace it, we will lose signal.\nThesis justification:"Outliers were retained as tree-based ensemble models (Random Forest) are inherently robust to extreme values, \nand high metric values represent genuinely complex, defect-prone classes rather than measurement errors." '
